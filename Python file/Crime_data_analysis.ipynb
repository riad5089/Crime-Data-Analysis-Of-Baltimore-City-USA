# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df=pd.read_csv("Crime_data.csv")

# %%
# pd.set_option('max_rows', None)

# %%
df
# Out:
#             CrimeDateTime CrimeCode            Location        Description  \
# 0     6/24/2023, 10:01 AM        4B       600 LUCIA AVE       AGG. ASSAULT
# 1     6/24/2023, 10:01 AM        4B       600 LUCIA AVE       AGG. ASSAULT
# 2     6/24/2023, 10:01 AM        4B       600 LUCIA AVE       AGG. ASSAULT
# 3     6/24/2023, 10:01 AM       3JK       600 LUCIA AVE            ROBBERY
# 4      6/24/2023, 9:45 AM        5A       3200 LILY AVE           BURGLARY
# ...                   ...       ...                 ...                ...
# 2995    5/5/2023, 4:00 AM        5B       6800 FAIT AVE           BURGLARY
# 2996    5/5/2023, 3:00 AM        7C   5700 MAPLEHILL RD         AUTO THEFT
# 2997   5/4/2023, 10:00 PM        6D   1600 HOMESTEAD ST  LARCENY FROM AUTO
# 2998    5/5/2023, 5:00 AM        7C   1300 GUILFORD AVE         AUTO THEFT
# 2999   4/24/2023, 1:15 PM        6D  2400 FLEETWOOD AVE  LARCENY FROM AUTO
#
#                 Weapon Victim_Gender  Victim_Age                Victim_Race  \
# 0     PERSONAL_WEAPONS             F        15.0  BLACK_OR_AFRICAN_AMERICAN
# 1     PERSONAL_WEAPONS             F        15.0  BLACK_OR_AFRICAN_AMERICAN
# 2     PERSONAL_WEAPONS             F        27.0  BLACK_OR_AFRICAN_AMERICAN
# 3     PERSONAL_WEAPONS             M        25.0  BLACK_OR_AFRICAN_AMERICAN
# 4                  NaN             M        48.0                        NaN
# ...                ...           ...         ...                        ...
# 2995               NaN           NaN         NaN                        NaN
# 2996               NaN             F        41.0  BLACK_OR_AFRICAN_AMERICAN
# 2997               NaN             M        64.0  BLACK_OR_AFRICAN_AMERICAN
# 2998               NaN             F        35.0  BLACK_OR_AFRICAN_AMERICAN
# 2999               NaN             M        40.0  BLACK_OR_AFRICAN_AMERICAN
#
#        District
# 0     SOUTHWEST
# 1     SOUTHWEST
# 2     SOUTHWEST
# 3     SOUTHWEST
# 4      SOUTHERN
# ...         ...
# 2995  SOUTHEAST
# 2996  NORTHEAST
# 2997  NORTHEAST
# 2998    CENTRAL
# 2999  NORTHEAST
#
# [3000 rows x 9 columns]

# %%
df.shape
# Out:
# (3000, 9)

# %% [markdown]
# # Null Value Handling

# %%
df.isna().sum()
# Out:
# CrimeDateTime       0
# CrimeCode           0
# Location           15
# Description         0
# Weapon           1817
# Victim_Gender     332
# Victim_Age        355
# Victim_Race       616
# District            2
# dtype: int64

# %%
df['Location'].fillna('Unknown', inplace=True)

# %%
df.Location.value_counts()
# Out:
# Unknown                15
# 3600 CLARINTH RD       13
# 3500 BOSTON ST         11
# 600 E PRATT ST          9
# 3600 POTEE ST           9
#                        ..
# 0 S EUTAW ST            1
# 4100 WOODHAVEN AVE      1
# 4200 GLENARM AVE        1
# 900 Stubblefield Ln     1
# 2400 FLEETWOOD AVE      1
# Name: Location, Length: 2083, dtype: int64

# %%
df['Weapon'].fillna("Other",inplace=True)

# %%
df.Weapon.isna().sum()
# Out:
# 0

# %%
df.Weapon.value_counts()
# Out:
# Other                       1817
# PERSONAL_WEAPONS             740
# HANDGUN                      137
# FIREARM                       93
# KNIFE_CUTTING_INSTRUMENT      68
# BLUNT_OBJECT                  52
# OTHER                         49
# UNKNOWN                       15
# AUTOMATIC_HANDGUN              9
# MOTOR_VEHICLE_VESSEL           8
# ASPHYXIATION                   4
# RIFLE                          4
# KNIFE                          2
# OTHER_FIREARM                  1
# SHOTGUN                        1
# Name: Weapon, dtype: int64

# %%
df.Victim_Gender.value_counts()
# Out:
# F             1421
# M             1167
# Male            56
# U               15
# Female           8
# Transgende       1
# Name: Victim_Gender, dtype: int64

# %%
df['Victim_Gender'] = df['Victim_Gender'].replace({'Female': 'F', 'Male': 'M'})

# %%
df['Victim_Gender'].value_counts()
# Out:
# F             1429
# M             1223
# U               15
# Transgende       1
# Name: Victim_Gender, dtype: int64

# %%
df['Victim_Gender'].fillna("U",inplace=True)

# %%
df['Victim_Gender'].value_counts()
# Out:
# F             1429
# M             1223
# U              347
# Transgende       1
# Name: Victim_Gender, dtype: int64

# %%
df['Victim_Gender'].isna().sum()
# Out:
# 0

# %%
df['Victim_Age'].max()
# Out:
# 99.0

# %%
df['Victim_Age'].min()
# Out:
# 0.0

# %%
df['Victim_Age'].unique()
# Out:
# array([15., 27., 25., 48., 30., 41., 21., 40., 29., 38., 54., 17., 39.,
#        22., 35., 76., 47., 37., 75., 24., 19., 31., 36., 49., 33., 46.,
#        78., 50., 28., 84., 53., 59., 32., 61., 26., 67., 57., 10., 18.,
#        62., 13., 42., nan, 34., 72., 56., 20., 51., 73., 66., 65., 45.,
#         8., 70., 23., 16., 52., 43., 68., 55., 44., 60., 71., 58., 64.,
#        74., 14., 12.,  2., 69., 81., 63., 88., 79.,  7.,  4., 80., 77.,
#         3., 83., 11., 82.,  9.,  0.,  1.,  5., 99.])

# %%
sns.distplot(x=df['Victim_Age'])
# Out:
# C:\Users\Abdur rahim nishad\AppData\Local\Temp\ipykernel_6796\1380858686.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['Victim_Age'])
# <Axes: ylabel='Density'>

# %%
round(df.Victim_Age.mean())
# Out:
# 38

# %%
df.Victim_Age.fillna(round(df.Victim_Age.mean()),inplace=True)

# %%
df.Victim_Age.isna().sum()
# Out:
# 0

# %%
df.Victim_Race.value_counts()
# Out:
# BLACK_OR_AFRICAN_AMERICAN                    1712
# WHITE                                         574
# ASIAN                                          49
# UNKNOWN                                        29
# NATIVE_HAWAIIAN_OR_OTHER_PACIFIC_ISLANDER      12
# AMERICAN_INDIAN_OR_ALASKA_NATIVE                8
# Name: Victim_Race, dtype: int64

# %%
df["Victim_Race"].fillna("OTHER",inplace=True)

# %%
df["Victim_Race"].replace("UNKNOWN","OTHER",inplace=True)

# %%
df.Victim_Race.value_counts()
# Out:
# BLACK_OR_AFRICAN_AMERICAN                    1712
# OTHER                                         645
# WHITE                                         574
# ASIAN                                          49
# NATIVE_HAWAIIAN_OR_OTHER_PACIFIC_ISLANDER      12
# AMERICAN_INDIAN_OR_ALASKA_NATIVE                8
# Name: Victim_Race, dtype: int64

# %%
df.District.value_counts()
# Out:
# NORTHEAST    471
# SOUTHEAST    407
# NORTHERN     353
# SOUTHWEST    342
# CENTRAL      340
# SOUTHERN     335
# NORTHWEST    303
# EASTERN      232
# WESTERN      215
# Name: District, dtype: int64

# %%
df["District"].fillna(df["District"].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# CrimeDateTime    0
# CrimeCode        0
# Location         0
# Description      0
# Weapon           0
# Victim_Gender    0
# Victim_Age       0
# Victim_Race      0
# District         0
# dtype: int64

# %%
df
# Out:
#             CrimeDateTime CrimeCode            Location        Description  \
# 0     6/24/2023, 10:01 AM        4B       600 LUCIA AVE       AGG. ASSAULT
# 1     6/24/2023, 10:01 AM        4B       600 LUCIA AVE       AGG. ASSAULT
# 2     6/24/2023, 10:01 AM        4B       600 LUCIA AVE       AGG. ASSAULT
# 3     6/24/2023, 10:01 AM       3JK       600 LUCIA AVE            ROBBERY
# 4      6/24/2023, 9:45 AM        5A       3200 LILY AVE           BURGLARY
# ...                   ...       ...                 ...                ...
# 2995    5/5/2023, 4:00 AM        5B       6800 FAIT AVE           BURGLARY
# 2996    5/5/2023, 3:00 AM        7C   5700 MAPLEHILL RD         AUTO THEFT
# 2997   5/4/2023, 10:00 PM        6D   1600 HOMESTEAD ST  LARCENY FROM AUTO
# 2998    5/5/2023, 5:00 AM        7C   1300 GUILFORD AVE         AUTO THEFT
# 2999   4/24/2023, 1:15 PM        6D  2400 FLEETWOOD AVE  LARCENY FROM AUTO
#
#                 Weapon Victim_Gender  Victim_Age                Victim_Race  \
# 0     PERSONAL_WEAPONS             F        15.0  BLACK_OR_AFRICAN_AMERICAN
# 1     PERSONAL_WEAPONS             F        15.0  BLACK_OR_AFRICAN_AMERICAN
# 2     PERSONAL_WEAPONS             F        27.0  BLACK_OR_AFRICAN_AMERICAN
# 3     PERSONAL_WEAPONS             M        25.0  BLACK_OR_AFRICAN_AMERICAN
# 4                Other             M        48.0                      OTHER
# ...                ...           ...         ...                        ...
# 2995             Other             U        38.0                      OTHER
# 2996             Other             F        41.0  BLACK_OR_AFRICAN_AMERICAN
# 2997             Other             M        64.0  BLACK_OR_AFRICAN_AMERICAN
# 2998             Other             F        35.0  BLACK_OR_AFRICAN_AMERICAN
# 2999             Other             M        40.0  BLACK_OR_AFRICAN_AMERICAN
#
#        District
# 0     SOUTHWEST
# 1     SOUTHWEST
# 2     SOUTHWEST
# 3     SOUTHWEST
# 4      SOUTHERN
# ...         ...
# 2995  SOUTHEAST
# 2996  NORTHEAST
# 2997  NORTHEAST
# 2998    CENTRAL
# 2999  NORTHEAST
#
# [3000 rows x 9 columns]

# %%
df.CrimeDateTime.str.split(", ")[0][1]
# Out:
# '10:01 AM'

# %%
df['Date'] = df.CrimeDateTime.apply(lambda x:x.split(", ")[0])

# %%
df['Time'] = df.CrimeDateTime.apply(lambda x:x.split(", ")[1])

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#          CrimeDateTime CrimeCode       Location   Description  \
# 0  6/24/2023, 10:01 AM        4B  600 LUCIA AVE  AGG. ASSAULT
# 1  6/24/2023, 10:01 AM        4B  600 LUCIA AVE  AGG. ASSAULT
# 2  6/24/2023, 10:01 AM        4B  600 LUCIA AVE  AGG. ASSAULT
# 3  6/24/2023, 10:01 AM       3JK  600 LUCIA AVE       ROBBERY
# 4   6/24/2023, 9:45 AM        5A  3200 LILY AVE      BURGLARY
#
#              Weapon Victim_Gender  Victim_Age                Victim_Race  \
# 0  PERSONAL_WEAPONS             F        15.0  BLACK_OR_AFRICAN_AMERICAN
# 1  PERSONAL_WEAPONS             F        15.0  BLACK_OR_AFRICAN_AMERICAN
# 2  PERSONAL_WEAPONS             F        27.0  BLACK_OR_AFRICAN_AMERICAN
# 3  PERSONAL_WEAPONS             M        25.0  BLACK_OR_AFRICAN_AMERICAN
# 4             Other             M        48.0                      OTHER
#
#     District       Date      Time
# 0  SOUTHWEST 2023-06-24  10:01 AM
# 1  SOUTHWEST 2023-06-24  10:01 AM
# 2  SOUTHWEST 2023-06-24  10:01 AM
# 3  SOUTHWEST 2023-06-24  10:01 AM
# 4   SOUTHERN 2023-06-24   9:45 AM

# %%
df.Time.value_counts()
# Out:
# 2:00 AM     86
# 11:00 PM    78
# 3:00 AM     77
# 4:00 AM     71
# 12:00 AM    68
#             ..
# 5:57 PM      1
# 8:40 PM      1
# 12:52 AM     1
# 6:10 PM      1
# 10:13 AM     1
# Name: Time, Length: 674, dtype: int64

# %%
df.Date.value_counts()
# Out:
# 2023-05-15    173
# 2023-05-07    151
# 2023-05-06    150
# 2023-05-16    143
# 2023-06-04    141
# 2023-06-22    135
# 2023-06-12    134
# 2023-04-26    132
# 2023-06-03    123
# 2023-06-14    123
# 2023-04-25    122
# 2023-06-23    121
# 2023-06-11    108
# 2023-06-21    107
# 2023-06-13    106
# 2023-04-27    100
# 2023-06-24     99
# 2023-06-02     98
# 2023-05-05     97
# 2023-04-24     77
# 2023-05-14     75
# 2023-05-17     70
# 2023-05-26     61
# 2023-05-08     49
# 2023-06-20     46
# 2023-06-15     44
# 2023-04-28     34
# 2023-05-25     33
# 2023-06-05     33
# 2023-05-04     31
# 2023-05-27     26
# 2023-06-01     19
# 2023-06-25     14
# 2023-04-17     10
# 2023-05-09      6
# 2023-04-16      4
# 2023-04-18      3
# 2023-05-18      2
# Name: Date, dtype: int64

# %%
df.head()
# Out:
#          CrimeDateTime CrimeCode       Location   Description  \
# 0  6/24/2023, 10:01 AM        4B  600 LUCIA AVE  AGG. ASSAULT
# 1  6/24/2023, 10:01 AM        4B  600 LUCIA AVE  AGG. ASSAULT
# 2  6/24/2023, 10:01 AM        4B  600 LUCIA AVE  AGG. ASSAULT
# 3  6/24/2023, 10:01 AM       3JK  600 LUCIA AVE       ROBBERY
# 4   6/24/2023, 9:45 AM        5A  3200 LILY AVE      BURGLARY
#
#              Weapon Victim_Gender  Victim_Age                Victim_Race  \
# 0  PERSONAL_WEAPONS             F        15.0  BLACK_OR_AFRICAN_AMERICAN
# 1  PERSONAL_WEAPONS             F        15.0  BLACK_OR_AFRICAN_AMERICAN
# 2  PERSONAL_WEAPONS             F        27.0  BLACK_OR_AFRICAN_AMERICAN
# 3  PERSONAL_WEAPONS             M        25.0  BLACK_OR_AFRICAN_AMERICAN
# 4             Other             M        48.0                      OTHER
#
#     District       Date      Time
# 0  SOUTHWEST 2023-06-24  10:01 AM
# 1  SOUTHWEST 2023-06-24  10:01 AM
# 2  SOUTHWEST 2023-06-24  10:01 AM
# 3  SOUTHWEST 2023-06-24  10:01 AM
# 4   SOUTHERN 2023-06-24   9:45 AM

# %%
df=df.drop("CrimeDateTime",axis=1)

# %%
df
# Out:
#      CrimeCode            Location        Description            Weapon  \
# 0           4B       600 LUCIA AVE       AGG. ASSAULT  PERSONAL_WEAPONS
# 1           4B       600 LUCIA AVE       AGG. ASSAULT  PERSONAL_WEAPONS
# 2           4B       600 LUCIA AVE       AGG. ASSAULT  PERSONAL_WEAPONS
# 3          3JK       600 LUCIA AVE            ROBBERY  PERSONAL_WEAPONS
# 4           5A       3200 LILY AVE           BURGLARY             Other
# ...        ...                 ...                ...               ...
# 2995        5B       6800 FAIT AVE           BURGLARY             Other
# 2996        7C   5700 MAPLEHILL RD         AUTO THEFT             Other
# 2997        6D   1600 HOMESTEAD ST  LARCENY FROM AUTO             Other
# 2998        7C   1300 GUILFORD AVE         AUTO THEFT             Other
# 2999        6D  2400 FLEETWOOD AVE  LARCENY FROM AUTO             Other
#
#      Victim_Gender  Victim_Age                Victim_Race   District  \
# 0                F        15.0  BLACK_OR_AFRICAN_AMERICAN  SOUTHWEST
# 1                F        15.0  BLACK_OR_AFRICAN_AMERICAN  SOUTHWEST
# 2                F        27.0  BLACK_OR_AFRICAN_AMERICAN  SOUTHWEST
# 3                M        25.0  BLACK_OR_AFRICAN_AMERICAN  SOUTHWEST
# 4                M        48.0                      OTHER   SOUTHERN
# ...            ...         ...                        ...        ...
# 2995             U        38.0                      OTHER  SOUTHEAST
# 2996             F        41.0  BLACK_OR_AFRICAN_AMERICAN  NORTHEAST
# 2997             M        64.0  BLACK_OR_AFRICAN_AMERICAN  NORTHEAST
# 2998             F        35.0  BLACK_OR_AFRICAN_AMERICAN    CENTRAL
# 2999             M        40.0  BLACK_OR_AFRICAN_AMERICAN  NORTHEAST
#
#            Date      Time
# 0    2023-06-24  10:01 AM
# 1    2023-06-24  10:01 AM
# 2    2023-06-24  10:01 AM
# 3    2023-06-24  10:01 AM
# 4    2023-06-24   9:45 AM
# ...         ...       ...
# 2995 2023-05-05   4:00 AM
# 2996 2023-05-05   3:00 AM
# 2997 2023-05-04  10:00 PM
# 2998 2023-05-05   5:00 AM
# 2999 2023-04-24   1:15 PM
#
# [3000 rows x 10 columns]

# %%
df[df["Victim_Age"]<=10]
# Out:
#      CrimeCode             Location     Description                    Weapon  \
# 66          4E     100 S CHARLES ST  COMMON ASSAULT          PERSONAL_WEAPONS
# 97          4E       300 E PRATT ST  COMMON ASSAULT          PERSONAL_WEAPONS
# 133         4E  1400 BLOOMFIELD AVE  COMMON ASSAULT          PERSONAL_WEAPONS
# 335        3AF       2600 MILES AVE         ROBBERY          PERSONAL_WEAPONS
# 478         4C    3900 GLEN HUNT RD    AGG. ASSAULT          PERSONAL_WEAPONS
# 743         4A     3600 CLARINTH RD    AGG. ASSAULT                   HANDGUN
# 796         4E      4500 PARKTON ST  COMMON ASSAULT          PERSONAL_WEAPONS
# 820         4A     3600 CLARINTH RD    AGG. ASSAULT                   HANDGUN
# 903         4A     3600 CLARINTH RD    AGG. ASSAULT                   HANDGUN
# 905         4A     3600 CLARINTH RD    AGG. ASSAULT                   HANDGUN
# 906         4A     3600 CLARINTH RD    AGG. ASSAULT                   HANDGUN
# 907         4A     3600 CLARINTH RD    AGG. ASSAULT                   HANDGUN
# 937         4B     3500 LYNDALE AVE    AGG. ASSAULT              BLUNT_OBJECT
# 1242        4A     3600 CLARINTH RD    AGG. ASSAULT                   HANDGUN
# 1252        4A     3600 CLARINTH RD    AGG. ASSAULT                   HANDGUN
# 1385        4B     2500 Tolley Rear    AGG. ASSAULT          PERSONAL_WEAPONS
# 1664        4E       0 W PRESTON ST  COMMON ASSAULT          PERSONAL_WEAPONS
# 1721        6G    100 NORTH BEND RD         LARCENY                     Other
# 1778        7C     3600 RAYMONN AVE      AUTO THEFT                     Other
# 1805        4E   1500 N DUKELAND ST  COMMON ASSAULT          PERSONAL_WEAPONS
# 2083        4E      1800 ORLEANS ST  COMMON ASSAULT          PERSONAL_WEAPONS
# 2179        4B       300 S EAST AVE    AGG. ASSAULT          PERSONAL_WEAPONS
# 2254       3JF   3800 BARRINGTON RD         ROBBERY                   HANDGUN
# 2481        4E   1400 E Monument St  COMMON ASSAULT          PERSONAL_WEAPONS
# 2555        4E       300 WARREN AVE  COMMON ASSAULT          PERSONAL_WEAPONS
# 2559        4E       300 WARREN AVE  COMMON ASSAULT          PERSONAL_WEAPONS
# 2666        8H       5200 READY AVE           ARSON                     Other
# 2669        8H       5200 READY AVE           ARSON                     Other
# 2751       3NK     5500 EASTERN AVE         ROBBERY  KNIFE_CUTTING_INSTRUMENT
# 2787        4E    600 WILDWOOD PKWY  COMMON ASSAULT          PERSONAL_WEAPONS
# 2929        4E    1200 DELLWOOD AVE  COMMON ASSAULT                     Other
# 2962        4C        600 ARSAN AVE    AGG. ASSAULT                     OTHER
# 2963        4C        600 ARSAN AVE    AGG. ASSAULT                     OTHER
# 2964        4C        600 ARSAN AVE    AGG. ASSAULT                     OTHER
# 2989        4E          700 GOLD ST  COMMON ASSAULT          PERSONAL_WEAPONS
# 2990        4E          700 GOLD ST  COMMON ASSAULT          PERSONAL_WEAPONS
#
#      Victim_Gender  Victim_Age                Victim_Race   District  \
# 66               F        10.0                      WHITE    CENTRAL
# 97               M        10.0                      WHITE    CENTRAL
# 133              F         8.0  BLACK_OR_AFRICAN_AMERICAN  SOUTHWEST
# 335              M         2.0                      WHITE   NORTHERN
# 478              M        10.0  BLACK_OR_AFRICAN_AMERICAN  SOUTHWEST
# 743              M         8.0  BLACK_OR_AFRICAN_AMERICAN  NORTHWEST
# 796              F         7.0  BLACK_OR_AFRICAN_AMERICAN  SOUTHWEST
# 820              M         8.0  BLACK_OR_AFRICAN_AMERICAN  NORTHWEST
# 903              M         2.0  BLACK_OR_AFRICAN_AMERICAN  NORTHWEST
# 905              M         4.0  BLACK_OR_AFRICAN_AMERICAN  NORTHWEST
# 906              M        10.0  BLACK_OR_AFRICAN_AMERICAN  NORTHWEST
# 907              M        10.0  BLACK_OR_AFRICAN_AMERICAN  NORTHWEST
# 937              M         7.0  BLACK_OR_AFRICAN_AMERICAN  NORTHEAST
# 1242             M         4.0  BLACK_OR_AFRICAN_AMERICAN  NORTHWEST
# 1252             M        10.0  BLACK_OR_AFRICAN_AMERICAN  NORTHWEST
# 1385             M        10.0                      WHITE  SOUTHWEST
# 1664             M         7.0  BLACK_OR_AFRICAN_AMERICAN    CENTRAL
# 1721             M        10.0  BLACK_OR_AFRICAN_AMERICAN  SOUTHWEST
# 1778             F         7.0  BLACK_OR_AFRICAN_AMERICAN  NORTHEAST
# 1805             M         3.0  BLACK_OR_AFRICAN_AMERICAN  SOUTHWEST
# 2083             M         8.0  BLACK_OR_AFRICAN_AMERICAN    EASTERN
# 2179             M         8.0                      WHITE  SOUTHEAST
# 2254             M         7.0  BLACK_OR_AFRICAN_AMERICAN  NORTHWEST
# 2481             F         9.0  BLACK_OR_AFRICAN_AMERICAN    EASTERN
# 2555             F         3.0                      OTHER   SOUTHERN
# 2559             M         0.0                      OTHER   SOUTHERN
# 2666             F         1.0  BLACK_OR_AFRICAN_AMERICAN   NORTHERN
# 2669             M         2.0  BLACK_OR_AFRICAN_AMERICAN   NORTHERN
# 2751             M        10.0                      OTHER  SOUTHEAST
# 2787             M         5.0  BLACK_OR_AFRICAN_AMERICAN  SOUTHWEST
# 2929             F        10.0                      OTHER   NORTHERN
# 2962             M         4.0                      OTHER   SOUTHERN
# 2963             M        10.0                      OTHER   SOUTHERN
# 2964             M         5.0                      OTHER   SOUTHERN
# 2989             F         9.0  BLACK_OR_AFRICAN_AMERICAN    WESTERN
# 2990             M         8.0  BLACK_OR_AFRICAN_AMERICAN    WESTERN
#
#            Date      Time
# 66   2023-06-14  11:34 PM
# 97   2023-06-24  10:10 PM
# 133  2023-06-04  11:00 PM
# 335  2023-05-17   2:50 AM
# 478  2023-04-27  10:00 PM
# 743  2023-06-14  12:12 AM
# 796  2023-04-27   2:00 PM
# 820  2023-06-14  12:12 AM
# 903  2023-06-14  12:12 AM
# 905  2023-06-14  12:12 AM
# 906  2023-06-14  12:12 AM
# 907  2023-06-14  12:12 AM
# 937  2023-05-08   1:00 AM
# 1242 2023-06-14  12:12 AM
# 1252 2023-06-14  12:12 AM
# 1385 2023-04-26   8:25 PM
# 1664 2023-06-03  11:30 PM
# 1721 2023-04-25   8:30 PM
# 1778 2023-06-12   1:20 PM
# 1805 2023-04-25  10:25 AM
# 2083 2023-04-25  12:30 PM
# 2179 2023-05-05  11:00 PM
# 2254 2023-05-14   4:40 PM
# 2481 2023-05-06   3:20 AM
# 2555 2023-06-12   1:34 AM
# 2559 2023-06-12   1:34 AM
# 2666 2023-06-11   6:00 AM
# 2669 2023-06-11   6:00 AM
# 2751 2023-05-14  11:40 PM
# 2787 2023-05-04   8:00 PM
# 2929 2023-04-24   9:30 PM
# 2962 2023-05-15   2:20 AM
# 2963 2023-05-15   2:20 AM
# 2964 2023-05-15   2:20 AM
# 2989 2023-05-04   8:10 PM
# 2990 2023-05-04   8:10 PM

# %%
df['District'].value_counts()
# Out:
# NORTHEAST    473
# SOUTHEAST    407
# NORTHERN     353
# SOUTHWEST    342
# CENTRAL      340
# SOUTHERN     335
# NORTHWEST    303
# EASTERN      232
# WESTERN      215
# Name: District, dtype: int64

# %%
df['Year']=df['Date'].dt.year

# %%
df['Day']=df['Date'].dt.day

# %%
df['Month']=df['Date'].dt.month_name()

# %%
df.head()
# Out:
#   CrimeCode       Location   Description            Weapon Victim_Gender  \
# 0        4B  600 LUCIA AVE  AGG. ASSAULT  PERSONAL_WEAPONS             F
# 1        4B  600 LUCIA AVE  AGG. ASSAULT  PERSONAL_WEAPONS             F
# 2        4B  600 LUCIA AVE  AGG. ASSAULT  PERSONAL_WEAPONS             F
# 3       3JK  600 LUCIA AVE       ROBBERY  PERSONAL_WEAPONS             M
# 4        5A  3200 LILY AVE      BURGLARY             Other             M
#
#    Victim_Age                Victim_Race   District       Date      Time  \
# 0        15.0  BLACK_OR_AFRICAN_AMERICAN  SOUTHWEST 2023-06-24  10:01 AM
# 1        15.0  BLACK_OR_AFRICAN_AMERICAN  SOUTHWEST 2023-06-24  10:01 AM
# 2        27.0  BLACK_OR_AFRICAN_AMERICAN  SOUTHWEST 2023-06-24  10:01 AM
# 3        25.0  BLACK_OR_AFRICAN_AMERICAN  SOUTHWEST 2023-06-24  10:01 AM
# 4        48.0                      OTHER   SOUTHERN 2023-06-24   9:45 AM
#
#    Year  Day Month
# 0  2023   24  June
# 1  2023   24  June
# 2  2023   24  June
# 3  2023   24  June
# 4  2023   24  June

# %%
df.Month.value_counts()
# Out:
# June     1451
# May      1067
# April     482
# Name: Month, dtype: int64

# %%
print(df[['Month','Day']].value_counts())
# Out:
# Month  Day
# May    15     173
#        7      151
#        6      150
#        16     143
# June   4      141
#        22     135
#        12     134
# April  26     132
# June   14     123
#        3      123
# April  25     122
# June   23     121
#        11     108
#        21     107
#        13     106
# April  27     100
# June   24      99
#        2       98
# May    5       97
# April  24      77
# May    14      75
#        17      70
#        26      61
#        8       49
# June   20      46
#        15      44
# April  28      34
# June   5       33
# May    25      33
#        4       31
#        27      26
# June   1       19
#        25      14
# April  17      10
# May    9        6
# April  16       4
#        18       3
# May    18       2
# dtype: int64

# %%
df.groupby(['Month','Victim_Race']).size().reset_index(name='Count')
# Out:
#     Month                                Victim_Race  Count
# 0   April           AMERICAN_INDIAN_OR_ALASKA_NATIVE      4
# 1   April                                      ASIAN     10
# 2   April                  BLACK_OR_AFRICAN_AMERICAN    271
# 3   April  NATIVE_HAWAIIAN_OR_OTHER_PACIFIC_ISLANDER      4
# 4   April                                      OTHER    109
# 5   April                                      WHITE     84
# 6    June           AMERICAN_INDIAN_OR_ALASKA_NATIVE      4
# 7    June                                      ASIAN     25
# 8    June                  BLACK_OR_AFRICAN_AMERICAN    830
# 9    June  NATIVE_HAWAIIAN_OR_OTHER_PACIFIC_ISLANDER      7
# 10   June                                      OTHER    313
# 11   June                                      WHITE    272
# 12    May                                      ASIAN     14
# 13    May                  BLACK_OR_AFRICAN_AMERICAN    611
# 14    May  NATIVE_HAWAIIAN_OR_OTHER_PACIFIC_ISLANDER      1
# 15    May                                      OTHER    223
# 16    May                                      WHITE    218

# %%
df.Victim_Age.dtype
# Out:
# dtype('float64')

# %%
df.Description.value_counts()
# Out:
# AUTO THEFT              760
# COMMON ASSAULT          622
# LARCENY                 532
# AGG. ASSAULT            322
# LARCENY FROM AUTO       261
# ROBBERY                 184
# BURGLARY                170
# SHOOTING                 52
# ROBBERY - CARJACKING     33
# ROBBERY - COMMERCIAL     24
# RAPE                     15
# HOMICIDE                 13
# ARSON                    12
# Name: Description, dtype: int64

# %%
df.to_csv("Crime_clean_data.csv",index=False)
